# %% [markdown]
# ## Step 1: Stat block translation for the target system
#
# Prompt:
# "Read the target system stat block examples provided. Using `SystemAdaptationGuide.md` as the architecture reference, propose regex patterns and transformation rules that map this system's fields to canonical fields in the guide. Focus only on mapping field names (hp, ac, saves, actions) — do not change system-specific mechanic meanings."

# %% [markdown]
# ## Step 2: Adapter code scaffold
#
# Prompt:
# "Generate a minimal `system-profiles/<Target>/adapter.py` that contains a `to_canonical()` function. Use the translation map template from the architecture guide and create test inputs for 3 types of stat blocks (weak, normal, boss). Suggest any special transformations."

# %% [markdown]
# ## Step 3: Final mapping validation plan
#
# Prompt:
# "Produce a validation plan with sample tests that take in example stat blocks from the target system, run them through the `to_canonical()` function, and assert canonical output matches expected structure (example JSON shapes). Include a checklist for handling edge cases and how to collect more sample data."
