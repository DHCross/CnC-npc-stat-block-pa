# %% [markdown]
# # NotebookLM: System Adaptation — Step 2: Stat block translation
#
# Context: There is a `src/lib` parser for C&C stat blocks. We want a PF2e parser.
#
# Prompt:
# "Compare the C&C stat-block format used in this repo (search for `stat block`, `npcs`, `canonical` usage) to sample Pathfinder 2e stat blocks I will upload in the next cell/file.
# Using that comparison, generate example regex patterns and transformation rules for PF2e stat blocks that will map PF2e attributes to the canonical fields used by this repo (name, hp, ac, saves, actions, special traits).
# Also provide at least two PF2e-specific edge cases (e.g., variable HP due to templates or conditional resistances) and how to normalize them."

# %% [markdown]
# # NotebookLM: System Adaptation — Step 3: File structure & scaffolding
#
# Prompt:
# "Generate a directory and file structure for a `pathfinder2-workbench` repo based on `CnC-npc-stat-block-pa`.
# For each proposed file, explain whether it should be copied verbatim from the source repo, adapted, or created from scratch. Include concrete examples: which parser(s), which `system-profiles` mapping, and any test fixtures to include."

# %% [markdown]
# # NotebookLM: System Adaptation — Step 4: Prioritized implementation plan
#
# Prompt:
# "Create a prioritized 6–8 week implementation plan for the new `pathfinder2-workbench`. Include milestones for: schema design, parser implementation, adapter `to_canonical`, test fixtures, NotebookLM validation with canonical outputs, and sample Storybook story for the pipeline UI.
# Also include unit-test ideas and a small release check list for the first alpha."
