# %% [markdown]
# ## Step 1: High-level architecture separation
#
# Prompt:
# "You will be given the repository code and `docs/SystemAdaptationGuide.md`.
# List the core architectural components found in this project (parsers, canonical schema, validators, chunking tools, output export). For each component, say: (a) is it universal to any RPG system or (b) is it system-specific to C&C and should be isolated."

# %% [markdown]
# ## Step 2: Ask for a translation map template
#
# Prompt:
# "Using the architecture guide, produce a translation map template (a YAML snippet) showing how to map a target system fields to the canonical schema. Keep descriptions generic (e.g., 'stat name', 'hit points formula', 'armor class value') and *do not* map to C&C specific names like CL."

# %% [markdown]
# ## Step 3: Scaffolding & tests
#
# Prompt:
# "Propose a minimal file scaffolding, tests, and `system-profiles/<NewSystem>/adapter.py` mocks that would allow a developer to implement `to_canonical()` for a new system without copying any C&C rules. Also mention what examples to upload to NotebookLM next (e.g., stat block formats, canonical output examples)."
